# %% [markdown]
# # DyrtyVision - Data Exploration
#
# Notebook for exploring downloaded datasets, inspecting class distributions,
# and previewing augmentations before training.

# %%
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np

from src.data.convert import CLASS_NAMES, CLASS_MAPPING

# %%
# TODO: Load dataset and inspect class distribution
print(f"Classes: {CLASS_NAMES}")
print(f"Mapping: {CLASS_MAPPING}")
